# %% [markdown]
# # LABORATORIUM nr <span style='color:Orange'>4</span>

# %% [markdown]
# ## Import LIB(s)

# %%
import pandas as pd
from datetime import datetime
from pytz import utc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dane= pd.read_csv("reviews_courses.csv", parse_dates=["Timestamp"])

# %%
dane
# Out:
#                                       Course Name                 Timestamp  \
# 0              The Python Course: AI/ML in Python 2021-04-02 06:25:52+00:00
# 1              The Python Course: AI/ML in Python 2021-04-02 05:12:34+00:00
# 2              The Python Course: AI/ML in Python 2021-04-02 05:11:03+00:00
# 3              The Python Course: AI/ML in Python 2021-04-02 03:33:24+00:00
# 4              The Python Course: AI/ML in Python 2021-04-02 03:31:49+00:00
# ...                                           ...                       ...
# 44995  The Python Course: From Beginner to Expert 2018-01-01 01:11:26+00:00
# 44996          The Python Course: AI/ML in Python 2018-01-01 01:09:56+00:00
# 44997          The Python Course: AI/ML in Python 2018-01-01 01:08:11+00:00
# 44998  The Python Course: From Beginner to Expert 2018-01-01 01:05:26+00:00
# 44999          The Python Course: AI/ML in Python 2018-01-01 01:01:16+00:00
#
#        Rating Comment
# 0         4.0     NaN
# ...

# %%
dane["Course Name"].iloc[44999]
# Out:
# 'The Python Course: AI/ML in Python'

# %%
dane.iloc[0]
# Out:
# Course Name    The Python Course: AI/ML in Python
# Timestamp               2021-04-02 06:25:52+00:00
# Rating                                        4.0
# Comment                                       NaN
# Name: 0, dtype: object

# %%
dane["Course Name"]
dane.head
# Out:
# <bound method NDFrame.head of                                       Course Name                 Timestamp  \
# 0              The Python Course: AI/ML in Python 2021-04-02 06:25:52+00:00
# 1              The Python Course: AI/ML in Python 2021-04-02 05:12:34+00:00
# 2              The Python Course: AI/ML in Python 2021-04-02 05:11:03+00:00
# 3              The Python Course: AI/ML in Python 2021-04-02 03:33:24+00:00
# 4              The Python Course: AI/ML in Python 2021-04-02 03:31:49+00:00
# ...                                           ...                       ...
# 44995  The Python Course: From Beginner to Expert 2018-01-01 01:11:26+00:00
# 44996          The Python Course: AI/ML in Python 2018-01-01 01:09:56+00:00
# 44997          The Python Course: AI/ML in Python 2018-01-01 01:08:11+00:00
# 44998  The Python Course: From Beginner to Expert 2018-01-01 01:05:26+00:00
# 44999          The Python Course: AI/ML in Python 2018-01-01 01:01:16+00:00
#
#        Rating Comment
# ...

# %%
dane[["Course Name","Timestamp"]].iloc[0:4]
# Out:
#                           Course Name                  Timestamp
# 0  The Python Course: AI/ML in Python  2021-04-02 06:25:52+00:00
# 1  The Python Course: AI/ML in Python  2021-04-02 05:12:34+00:00
# 2  The Python Course: AI/ML in Python  2021-04-02 05:11:03+00:00
# 3  The Python Course: AI/ML in Python  2021-04-02 03:33:24+00:00

# %%
dane["Rating"].hist()
# Out:
# <Axes: >

# %%
dane.count()
# Out:
# Course Name    45000
# Timestamp      45000
# Rating         45000
# Comment         6799
# dtype: int64

# %%
dane["Course Name"].unique()
# Out:
# array(['The Python Course: AI/ML in Python',
#        'The Python Course: OpenCV in Python',
#        'The Python Course: 100 Excercises for Beginners',
#        'The Python Course: Interactive Visualizations',
#        'The Python Course: From Beginner to Expert',
#        'The Python Excercises:Data Processing by use of Python',
#        'The Python Excercises: From Beginner to Expert',
#        'Learn GIS in One Hour'], dtype=object)

# %% [markdown]
# Wyświetlenie Ratingu > 5 i nazwa kursu odpowiednia

# %%
limitedTimestamps=dane[
    (dane["Timestamp"]>=datetime(2020,7,1, tzinfo=utc))& 
    (dane["Timestamp"]<=datetime(2020,12,31, tzinfo=utc))
]
limitedTimestamps
# Out:
#                                         Course Name                 Timestamp  \
# 3065  The Python Course: Interactive Visualizations 2020-12-30 23:28:34+00:00
# 3066             The Python Course: AI/ML in Python 2020-12-30 22:59:02+00:00
# 3067             The Python Course: AI/ML in Python 2020-12-30 22:40:10+00:00
# 3068             The Python Course: AI/ML in Python 2020-12-30 21:56:41+00:00
# 3069             The Python Course: AI/ML in Python 2020-12-30 21:14:34+00:00
# ...                                             ...                       ...
# 9729             The Python Course: AI/ML in Python 2020-07-01 03:09:44+00:00
# 9730             The Python Course: AI/ML in Python 2020-07-01 03:09:12+00:00
# 9731             The Python Course: AI/ML in Python 2020-07-01 02:40:58+00:00
# 9732             The Python Course: AI/ML in Python 2020-07-01 02:04:02+00:00
# 9733             The Python Course: AI/ML in Python 2020-07-01 00:01:34+00:00
#
# ...

# %%
import pandas as pd
from datetime import datetime
from pytz import utc
import matplotlib.pyplot as plt
# %matplotlib inline

dane= pd.read_csv("reviews_courses.csv", parse_dates=["Timestamp"])

# %%
dane
# Out:
#                                       Course Name                 Timestamp  \
# 0              The Python Course: AI/ML in Python 2021-04-02 06:25:52+00:00
# 1              The Python Course: AI/ML in Python 2021-04-02 05:12:34+00:00
# 2              The Python Course: AI/ML in Python 2021-04-02 05:11:03+00:00
# 3              The Python Course: AI/ML in Python 2021-04-02 03:33:24+00:00
# 4              The Python Course: AI/ML in Python 2021-04-02 03:31:49+00:00
# ...                                           ...                       ...
# 44995  The Python Course: From Beginner to Expert 2018-01-01 01:11:26+00:00
# 44996          The Python Course: AI/ML in Python 2018-01-01 01:09:56+00:00
# 44997          The Python Course: AI/ML in Python 2018-01-01 01:08:11+00:00
# 44998  The Python Course: From Beginner to Expert 2018-01-01 01:05:26+00:00
# 44999          The Python Course: AI/ML in Python 2018-01-01 01:01:16+00:00
#
#        Rating Comment
# 0         4.0     NaN
# ...

# %%
# Out:
# (1188, 1)

# %%
# Out:
# Index(['Course Name', 'Timestamp', 'Rating', 'Comment', 'Day'], dtype='object')

# %%
# Out:
# Index(['Course Name', 'Timestamp', 'Rating'], dtype='object')

# %%
dane["Day"]=dane['Timestamp'].dt.date
day_average=dane.groupby(['Day']).mean(numeric_only=True)
day_average.head()
x=day_average.index
y=day_average['Rating']
plt.figure(
    figsize=(25,10)
)
plt.plot(x,y)

# %%
# Out:
#                                       Course Name                 Timestamp  \
# 0              The Python Course: AI/ML in Python 2021-04-02 06:25:52+00:00
# 1              The Python Course: AI/ML in Python 2021-04-02 05:12:34+00:00
# 2              The Python Course: AI/ML in Python 2021-04-02 05:11:03+00:00
# 3              The Python Course: AI/ML in Python 2021-04-02 03:33:24+00:00
# 4              The Python Course: AI/ML in Python 2021-04-02 03:31:49+00:00
# ...                                           ...                       ...
# 44995  The Python Course: From Beginner to Expert 2018-01-01 01:11:26+00:00
# 44996          The Python Course: AI/ML in Python 2018-01-01 01:09:56+00:00
# 44997          The Python Course: AI/ML in Python 2018-01-01 01:08:11+00:00
# 44998  The Python Course: From Beginner to Expert 2018-01-01 01:05:26+00:00
# 44999          The Python Course: AI/ML in Python 2018-01-01 01:01:16+00:00
#
#        Rating Comment  Day  Week  Year
# ...

# %%
# Out:
#                                       Course Name                 Timestamp  \
# 0              The Python Course: AI/ML in Python 2021-04-02 06:25:52+00:00
# 1              The Python Course: AI/ML in Python 2021-04-02 05:12:34+00:00
# 2              The Python Course: AI/ML in Python 2021-04-02 05:11:03+00:00
# 3              The Python Course: AI/ML in Python 2021-04-02 03:33:24+00:00
# 4              The Python Course: AI/ML in Python 2021-04-02 03:31:49+00:00
# ...                                           ...                       ...
# 44995  The Python Course: From Beginner to Expert 2018-01-01 01:11:26+00:00
# 44996          The Python Course: AI/ML in Python 2018-01-01 01:09:56+00:00
# 44997          The Python Course: AI/ML in Python 2018-01-01 01:08:11+00:00
# 44998  The Python Course: From Beginner to Expert 2018-01-01 01:05:26+00:00
# 44999          The Python Course: AI/ML in Python 2018-01-01 01:01:16+00:00
#
#        Rating Comment  Day  Week  Year  Month
# ...

# %%
dane["Week"]=dane["Timestamp"].dt.strftime("%Y-%U")
week_avg=dane.groupby(["Week"]).mean(numeric_only=True)
week_avg.head()
plt.figure(
    figsize=(25,10)
)
plt.plot(week_avg.index,week_avg["Rating"])

# %%
dane["Month"]=dane["Timestamp"].dt.strftime('%Y-%m')
month_avg=dane.groupby(dane["Month"]).mean(numeric_only=True)
plt.figure(
    figsize=(5,10)
)
plt.plot(month_avg.index,month_avg["Rating"])

# %%
month_average_course=dane.groupby(['Month','Course Name']).mean(numeric_only=True).unstack()
month_average_course.head()
plt.figure(
    figsize=(25,10)
)
plt.plot(month_average_course.index,month_average_course["Rating"])

# %%
month_average_course=dane.groupby(['Month','Course Name'])['Rating'].count().unstack()
month_average_course.head()
plt.figure(
    figsize=(25,10)
)
plt.plot(month_average_course.index,month_average_course)

# %%
dane
# Out:
#                                       Course Name                 Timestamp  \
# 0              The Python Course: AI/ML in Python 2021-04-02 06:25:52+00:00
# 1              The Python Course: AI/ML in Python 2021-04-02 05:12:34+00:00
# 2              The Python Course: AI/ML in Python 2021-04-02 05:11:03+00:00
# 3              The Python Course: AI/ML in Python 2021-04-02 03:33:24+00:00
# 4              The Python Course: AI/ML in Python 2021-04-02 03:31:49+00:00
# ...                                           ...                       ...
# 44995  The Python Course: From Beginner to Expert 2018-01-01 01:11:26+00:00
# 44996          The Python Course: AI/ML in Python 2018-01-01 01:09:56+00:00
# 44997          The Python Course: AI/ML in Python 2018-01-01 01:08:11+00:00
# 44998  The Python Course: From Beginner to Expert 2018-01-01 01:05:26+00:00
# 44999          The Python Course: AI/ML in Python 2018-01-01 01:01:16+00:00
#
#        Rating Comment    Month
# ...

# %%
dane
# Out:
#                                       Course Name                 Timestamp  \
# 0              The Python Course: AI/ML in Python 2021-04-02 06:25:52+00:00
# 1              The Python Course: AI/ML in Python 2021-04-02 05:12:34+00:00
# 2              The Python Course: AI/ML in Python 2021-04-02 05:11:03+00:00
# 3              The Python Course: AI/ML in Python 2021-04-02 03:33:24+00:00
# 4              The Python Course: AI/ML in Python 2021-04-02 03:31:49+00:00
# ...                                           ...                       ...
# 44995  The Python Course: From Beginner to Expert 2018-01-01 01:11:26+00:00
# 44996          The Python Course: AI/ML in Python 2018-01-01 01:09:56+00:00
# 44997          The Python Course: AI/ML in Python 2018-01-01 01:08:11+00:00
# 44998  The Python Course: From Beginner to Expert 2018-01-01 01:05:26+00:00
# 44999          The Python Course: AI/ML in Python 2018-01-01 01:01:16+00:00
#
#        Rating Comment    Month
# ...

# %%
dane["Day_Week"]=dane["Timestamp"].dt.strftime("%A")
dane["Week_Day_Number"]=dane["Timestamp"].dt.strftime("%w")
avg=dane.groupby(["Day_Week","Week_Day_Number"]).mean(numeric_only=True)
sorrted=avg.sort_values("Week_Day_Number")


# avg_by_day=dane.groupby(dane["Day_Week"])["Rating"].mean()
# avg_by_day.head()
# plt.figure(
#     figsize=(25,10)
# )
# plt.plot(avg_by_day.index,avg_by_day).sort_index()
# Out:
#                             Rating
# Day_Week Week_Day_Number
# Friday   5                4.455207
# Monday   1                4.449335
# Saturday 6                4.440274
# Sunday   0                4.439097
# Thursday 4                4.437880
